# %% [markdown]
# OOP (Object Oriented Programming)

# %%
'''
1 Class and object
2  Constructors
3 Types of OOP
    a Inheritance
    i single Inheritance
    ii Multi-level Inheritance
    iii Multiple Inheritance
b Encapsulation
c polymorphism
d Abstraction
'''

# %% [markdown]
# Class and Object

# %%
# class -> Blueprint of an object
class Dog:
    species = 'Mammel'
    breed = 'Husky'
    def sound(self):
        print('Brak')

# %%
#Object
# variable d store instance of an object
d = Dog()
print(d.species)
print (d.breed)
d.sound()
# Out:
# Mammel
# Husky
# Brak

# %% [markdown]
# ## constructor

# %%
#__init__
'''
types of varaible
1 Local varaiable -> Defined inside function or construction as an agruments
2 Instance varaible -> varaible that store data of local variable
3 Global varaiable ->
'''

# %%
class UserDetails:
    def __init__(self,first_name,last_name):
        self.first_name = first_name
        self.last_name = last_name
        def print_details(self):
            Print(f'First name:{self.first_name}')
            print(f'Last name:{self.last_name}')

# %%
user_accounts = []

# %%
ud = UserDetails('obin','Dhamala')
user_accounts.append(ud)

# %%
def login(email,password):
    for account in user_accounts:
        if email == account.email and password == account.password:
            print('Login sucessfull')
            return
    return'Incorrect email or password'

# %%
store product details.
- products name, products Quanity,  product price, product category, product Brand
- store data to all_products list
- search product using product name
    -if product found then print product name
    if product not found then show message 'products not found.'

# %%
class store:
    def __init__(self, productname, productQuantity, productprice,productcategory,productBrand):
        self.product_name = productname
        self.product_Quantity = productQuantity
        self.product_price = productprice 
        self.product_category = productcategory
        self.product_Brand = productBrand
    def print_details(self):
        print(f'product_name:{self.product_name}')
        print(f'product_Quantity:{self.product_Quantity}')
        print(f'product price:{self.product_price}')
        print(f'product category{self.product_category}')
        print(f'product Brand:{self.product_Brand}')

# %%
product_accounts = []

# %%
pd = store('nike','3','30000','shoes','gucci')
product_accounts.append(pd)

# %% [markdown]
# ##Inheritance

# %%
''' 
- it requires multiple classes.
- single inheritance
    - there must be one parent class and one child class.
    - To acess dta by child class, It must inherits parent class data.
'''
# Out:
# ' \n- it requires multiple classes.\n- single inheritance\n    - there must be one parent class and one child class.\n    - To acess dta by child class, It must inherits parent class data.\n'

# %%
'''
- Customer -> parent table -> Independent class
- Orders -> child table -> depends on customer

Rules of Inheritance
--------------------
1. child class must inherits/extends parent class.
2 If child class inherits parent class then child class must inherits parent class construction. using super()

# %%
Single Inheritance

# %%
class Customers:
    def __init__(self, customer_id, customer_name, customer_address, customer_phone,customer_type):
        self.customer_id = customer_id
        self.customer_name = customer_name
        self.customer_address = customer_address
        self.customer_phone = customer_phone
        self.customer_type = customer_type

        def customer_details(self):
            print(f'Customer Id: {self.customer_id}')
            print(f'Customer Name: {self.customer_name}')
            print(f'Customer Address: {self.customer_address}')
            print(f'Customer Phone: {self.customer_phone}')

# %%
class Orders(Customers):
    def __init__(self, order_id, order_status, order_date, order_destination, customer_id, 
                 customer_name, customer_address, customer_phone,customer_type):
        super().__init__( customer_id, customer_name, customer_address, customer_phone,customer_type)
        self.order_id = order_id
        self.order_status = order_status
        self.order_date = order_date
        self.order_destination = order_destination

    def order_details(self):
        print(f'Order Id: {self.order_id}')
        print(f'Order Status: {self.order_status}')
        print(f'Order Date: {self.order_date}')
        print(f'Order Destination: {self.order_destination}')

# %%
order_details = []

# %%
o = Orders(104, 'served', '2026-09-16', 'Dharan', 'Cust11', 'Ram', 'Ittahari', '9876543221', 'VIP')
order_details.append(o)

# %%
order_details

# %%
#order_details()
#o.customer_details()

# %%
def searchOrderbyCustomer(customer_name):
    customer_order
    for order in order_details:
        if order.customer_name == customer_name:
            return order.order_details()
            return f'No order found with customer name {customer_name}.'

# %%
searchOrderbyCustomer('Ram')
# Out:
# Order Id: 104
# Order Status: served
# Order Date: 2026-09-16
# Order Destination: Dharan

# %%
  customer_order.append(order.order_details())

# %%
def searchOrderbyCustomer(customer_name):
    customer_order = []
    for order in order_details:
        if order.customer_name == customer_name:
             customer_order.append(order.order_details())

        if customer_order:
            return customer_order
        return f'No order found with customer name {customer_name}.'

# %%
searchOrderbyCustomer('fdsf')
# Out:
# 'No order found with customer name fdsf.'

# %%
'''
-product -> parent table -> independent class
-category -> child table -> depends on product

# %%
class product:
    def __init__(self, product_id, product_name, brand_id, model_year, list_price):
        self.product_id = product_id
        self.product_name = product_name
        self.brand_id = brand_id
        self.model_year = model_year
        self.list_price = list_price

    def product_details(self):
        print(f'Product Id: {self.product_id}')
        print(f'Product Name: {self.product_name}')
        print(f'Brand Id: {self.brand_id}')
        print(f'Model Year: {self.model_year}')
        print(f'list Price: {self.list_price}')

# %%
class Category(product):
    def __init__(self, category_id, category_name, product_id, product_name, brand_id, model_year, list_price):
        self.category_id = category_id
        self.category_name = category_name

        def category_details(self):
         print(f'category Id: {self.category_id}')
         print(f'category Name: {self.category_name}')

# %%
category_details = []

# %%
c = Category(108, 'shoe', '111', 'nike', '123', '2025', '10000')
category_details.append(c)

# %%
category_details
# Out:
# [<__main__.Category at 0x159d0062cf0>, <__main__.Category at 0x159cfe9fed0>]

# %% [markdown]
# ###Multi level inheritance

# %%
'''
- It requries 3 or more than 3 classes.
- Class C Inheritits

# %%
class Customers:
    def __init__(self, customer_id, customer_name, customer_address, customer_phone,customer_type):
        self.customer_id = customer_id
        self.customer_name = customer_name
        self.customer_address = customer_address
        self.customer_phone = customer_phone
        self.customer_type = customer_type

    def customer_details(self):
        print(f'Customer Id: {self.customer_id}')
        print(f'Customer Name: {self.customer_name}')
        print(f'Customer Address: {self.customer_address}')
        print(f'Customer Phone: {self.customer_phone}')

# %%
class Orders(Customers):
    def __init__(self, order_id, order_status, order_date, order_destination, customer_id, 
                 customer_name, customer_address, customer_phone,customer_type):
        super().__init__( customer_id, customer_name, customer_address, customer_phone,customer_type)
        self.order_id = order_id
        self.order_status = order_status
        self.order_date = order_date
        self.order_destination = order_destination

    def order_details(self):
        print(f'Order Id: {self.order_id}')
        print(f'Order Status: {self.order_status}')
        print(f'Order Date: {self.order_date}')
        print(f'Order Destination: {self.order_destination}')

# %%
class Order_Items(Orders):
    def __init__(self, item_id, item_price, item_quantity, item_discount, order_id, order_status, order_date, order_destination, customer_id, 
                 customer_name, customer_address, customer_phone,customer_type):
        super().__init__(order_id, order_status, order_date, order_destination, customer_id, 
                 customer_name, customer_address, customer_phone,customer_type)
        self.item_id = item_id
        self.item_price = item_price
        self.item_quantity = item_quantity
        self.item_discount = item_discount

    def display_items(self):
        print(f'Item Id: {self.item_id}')
        print(f'Item Price: {self.item_price}')
        print(f'Item Quantity: {self.item_quantity}')
        print(f'Item Discount: {self.item_discount}')

# %%
oi = Order_Items('IT10', 200, 2, 20, 102, 'served', '2026-09-16', 'Dharan', 'Cust11', 'Ram', 'Ittahari', '9876543221', 'VIP')

# %%
oi.customer_details()
# Out:
# Customer Id: Cust11
# Customer Name: Ram
# Customer Address: Ittahari
# Customer Phone: 9876543221

# %%
oi.order_details()
# Out:
# Order Id: 102
# Order Status: served
# Order Date: 2026-09-16
# Order Destination: Dharan

# %%
oi.display_items()
# Out:
# Item Id: IT10
# Item Price: 200
# Item Quantity: 2
# Item Discount: 20

# %%
###Multiple Inheritance

# %%
class Customers:
    def __init__(self, customer_id, customer_name, customer_address, customer_phone,customer_type):
        self.customer_id = customer_id
        self.customer_name = customer_name
        self.customer_address = customer_address
        self.customer_phone = customer_phone
        self.customer_type = customer_type

    def customer_details(self):
        print(f'Customer Id: {self.customer_id}')
        print(f'Customer Name: {self.customer_name}')
        print(f'Customer Address: {self.customer_address}')
        print(f'Customer Phone: {self.customer_phone}')

# %%
class Staff:
    def __init__(self, staff_id, staff_name, staff_type, staff_position, staff_contact, staff_email):
        self.staff_id = staff_id
        self.staff_name = staff_name
        self.staff_type = staff_type
        self.staff_position = staff_position
        self.staff_contact = staff_contact
        self.staff_email = staff_email

    def staff_details(self):
        print(f'Staff Id: {self.staff_id}')
        print(f'Staff Name: {self.staff_name}')
        print(f'Staff Type: {self.staff_type}')
        print(f'Staff Position: {self.staff_position}')
        print(f'Staff Contact: {self.staff_contact}')
        print(f'Staff Email: {self.staff_email}')

# %%
class Orders(Customers, Staff):
    def __init__(self, order_id, order_status, order_date, order_destination, customer_id, 
                 customer_name, customer_address, customer_phone,customer_type, 
                 staff_id, staff_name, staff_type, staff_position, staff_contact, staff_email):
        Customers.__init__(self, customer_id, customer_name, customer_address, customer_phone,customer_type)
        Staff.__init__(self, staff_id, staff_name, staff_type, staff_position, staff_contact, staff_email)
        
        self.order_id = order_id
        self.order_status = order_status
        self.order_date = order_date
        self.order_destination = order_destination

    def order_details(self):
        print(f'Order Id: {self.order_id}')
        print(f'Order Status: {self.order_status}')
        print(f'Order Date: {self.order_date}')
        print(f'Order Destination: {self.order_destination}')

# %%
o = Orders(104, 'served', '2026-09-16', 'Dharan', 'Cust11', 'Ram', 'Ittahari', '9876543221', 'VIP',
           'ST100', 'Bob', 'Contract', 'Junior', '8765432190', 'bob@gmail.com')

# %%
o.customer_details()
# Out:
# Customer Id: Cust11
# Customer Name: Ram
# Customer Address: Ittahari
# Customer Phone: 9876543221

# %%
o.staff_details()
# Out:
# Staff Id: ST100
# Staff Name: Bob
# Staff Type: Contract
# Staff Position: Junior
# Staff Contact: 8765432190
# Staff Email: bob@gmail.com

# %%
o.order_details()
# Out:
# Order Id: 104
# Order Status: served
# Order Date: 2026-09-16
# Order Destination: Dharan

# %%
###Encapsulation

# %%
'''
Access Modifiers
------------------
1.Public
- self.var_name = var_name
-variable data can be access by an object inside the class or outside the class
2. Private (__) double underscore
-self.__var_name = var_name
- Variable data cannot be accessed outside the class
- Data must be accessed using fraction
3 protected (_) single underscore
- self._var_name = var_name
-variable data can be access inside the class and outside the class
- if we need to access data outside the class we have to use protective modifier symbol (_)
-data must be accessed using function
'''

# %%
#private accesss modifier

# %%
class Customers:
    def __init__(self, customer_id, customer_name, customer_address, customer_phone,customer_type):
        self.__customer_id = customer_id
        self.__customer_name = customer_name
        self.__customer_address = customer_address
        self.__customer_phone = customer_phone
        self.__customer_type = customer_type

    def customer_details(self):
        print(f'Customer Id: {self.__customer_id}')
        print(f'Customer Name: {self.__customer_name}')
        print(f'Customer Address: {self.__customer_address}')
        print(f'Customer Phone: {self.__customer_phone}')

# %%
class Orders(Customers):
    def __init__(self, order_id, order_status, order_date, order_destination, customer_id, 
                 customer_name, customer_address, customer_phone,customer_type):
        super().__init__( customer_id, customer_name, customer_address, customer_phone,customer_type)
        self.__order_id = order_id
        self.__order_status = order_status
        self.__order_date = order_date
        self.__order_destination = order_destination

    def order_details(self):
        print(f'Order Id: {self.__order_id}')
        print(f'Order Status: {self.__order_status}')
        print(f'Order Date: {self.__order_date}')
        print(f'Order Destination: {self.__order_destination}')

# %%
o = Orders(104, 'served', '2026-09-16', 'Dharan', 'Cust11', 'Ram', 'Ittahari', '9876543221', 'VIP')

# %%
o.customer_details()
# Out:
# Customer Id: Cust11
# Customer Name: Ram
# Customer Address: Ittahari
# Customer Phone: 9876543221

# %%
o.order_details()
# Out:
# Order Id: 104
# Order Status: served
# Order Date: 2026-09-16
# Order Destination: Dharan

# %% [markdown]
# ### protected Access Modifiers

# %%
class Customers:
    def __init__(self, customer_id, customer_name, customer_address, customer_phone,customer_type):
        self._customer_id = customer_id
        self._customer_name = customer_name
        self._customer_address = customer_address
        self._customer_phone = customer_phone
        self._customer_type = customer_type

    def customer_details(self):
        print(f'Customer Id: {self._customer_id}')
        print(f'Customer Name: {self._customer_name}')
        print(f'Customer Address: {self._customer_address}')
        print(f'Customer Phone: {self._customer_phone}')

# %%
class Orders(Customers):
    def __init__(self, order_id, order_status, order_date, order_destination, customer_id, 
                 customer_name, customer_address, customer_phone,customer_type):
        super().__init__( customer_id, customer_name, customer_address, customer_phone,customer_type)
        self._order_id = order_id
        self._order_status = order_status
        self._order_date = order_date
        self._order_destination = order_destination

    def order_details(self):
        print(f'Order Id: {self._order_id}')
        print(f'Order Status: {self._order_status}')
        print(f'Order Date: {self._order_date}')
        print(f'Order Destination: {self._order_destination}')

# %%
o = Orders(104, 'served', '2026-09-16', 'Dharan', 'Cust11', 'Ram', 'Ittahari', '9876543221', 'VIP')

# %%
o.customer_details()
# Out:
# Customer Id: Cust11
# Customer Name: Ram
# Customer Address: Ittahari
# Customer Phone: 9876543221

# %%
o.order_details()
# Out:
# Order Id: 104
# Order Status: served
# Order Date: 2026-09-16
# Order Destination: Dharan

# %%
o._customer_name
# Out:
# 'Ram'

# %% [markdown]
# ## polymorphism

# %%
'''
- It will have multiple independent classes with same function name and arguments
- All classes object must be executed using independent function

- A function with many forms is polymorshim
'''

# %%
class Esewa:
    def pay(self, send_from, send_to, amount):
        print (f'Rs.{amount} has been withdrawn using Esewa from {send_from} to {send_to}.')

class Khalti:
    def pay(self, send_from, send_to, amount):
        print (f'Rs.{amount} has been withdrawn using Khalti from {send_from} to {send_to}.')

class Fonepay:
    def pay(self, send_from, send_to, amount):
         print (f'Rs.{amount} has been withdrawn using Fonepay from {send_from} to {send_to}.')

# %%
def payment(obj, send_from, send_to, amount):
    obj.pay(send_from, send_to, amount)

# %%
'''
-Function Overloading - same function, same argument, Different Values
'''
# Out:
# '\n-Function Overloading - same function, same argument, Different Values\n'

# %%
payment(Fonepay(), 'Ram', 'shyam', 500)
# Out:
# Rs.500 has been withdrawn using Fonepay from Ram to shyam.

# %% [markdown]
# ## Abstraction

# %%
'''
- Abstraction -> Data hiding and implementation hiding
- To use abstraction conceot parent class must be an abstract class.
- If we create an abstract class there must be atleast one abstract function.

- If normal class -> Inheritance
- If abstract class -> Implements
'''
# Out:
# '\n- Abstraction -> Data hiding and implementation hiding\n- To use abstraction conceot parent class must be an abstract class.\n- If we create an abstract class there must be atleast one abstract function.\n\n- If normal class -> Inheritance\n- If abstract class -> Implements\n'

# %%
# abstract base class
from abc import ABC, abstractmethod

# %%
class MobileBanking(ABC):
    @abstractmethod
    def userDetails(self):
        pass

# %%
class NabilBankMobileBanking(MobileBanking):
    def connection(self):
        print('Connected to Nabil Bank Database Server...')

    def userDetails(self):
        print(f'A/C No.: 1234567890\nBalance: Rs.60000')

# %%
nb = NabilBankMobileBanking()

# %%
nb.connection()
# Out:
# Connected to Nabil Bank Database Server...

# %%
nb.userDetails()
# Out:
# A/C No.: 1234567890
# Balance: Rs.60000

# %%
# Create a polymorphism program for sending message.
'''
user can send message using four different platforms:
1 Messenger
2 Viber
3 Whatsapp
4 Instagram

- Message through these classes must be sent using one single function send_message().
-Function should accept these agruments:
- Sender
- receiver
- message

-program should show output as:
-{Receiver_name} received a message
-{sender_name} sent you a message
- Message: {message}

'''
# Out:
# '\nuser can send message using four different platforms:\n1 Messenger\n2 Viber\n3 Whatsapp\n4 Instagram\n\n- Message through these classes must be sent using one single function send_message().\n-Function should accept these agruments:\n- Sender\n- receiver\n- message\n\n-program should show output as:\n-{Receiver_name} received a message\n-{sender_name} sent you a message\n- Message: {message}\n\n'

# %%
class Messenger:
    def message(self, sender_name, receiver_name, message):
         print (f'{receiver_name} received a message  using Messenger from {sender_name} to {receiver_name}.')

class Viber:
    def message(self, sender_name, receiver_name, message):
        print (f'{sender_name} sent you a message  using Viber from {sender_name} to {receiver_name}.')

class Whatsapp:
    def message(self, sender_name, receiver_name, message):
        print (f'{message} sent you a message  using Whatsapp from {sender_name} to {receiver_name}.')
        
class Instagram:
     def message(self, sender_name, receiver_name, message):
          print (f'{message} sent you a message  using Whatsapp from {sender_name} to {receiver_name}.')

# %%
def sendmesaage(obj, sender_name, receiver_name, message):
    obj.message(sender_name, receiver_name, message)

# %%
sendmesaage(Viber(), 'obin', 'pujan', 'hello')
# Out:
# obin sent you a message  using Viber from obin to pujan.
