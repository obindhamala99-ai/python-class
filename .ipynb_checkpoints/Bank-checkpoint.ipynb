# %%
"".join(str(random.randint(1, 9)) for i in range(16))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 "".join(str(random.randint(1, 9)) for i in range(16))
#
# Cell In[1], line 1, in <genexpr>(.0)
# ----> 1 "".join(str(random.randint(1, 9)) for i in range(16))
#
# NameError: name 'random' is not defined

# %%
self.name[1:3]="".join(str(random.randint(1, 9)) for i in range(16))+'NB'

# %%
import random
class Bank:
    def __init__(self, name, job, initial_balance):
        self.name = name
        self.job = job
        self.initial_balance = initial_balance
        self.account_number = self.name[1:3]+"".join(str(random.randint(1, 9)) for i in range(16))+'NB'

        def depositAmount(self, amount):
            if amount >= 100:
                self.initial_balance += amount
                print(f'Rs.{amount} has been deposited in A/C no. {self.account_number}.')
            else:
                raise DepositAmountError('Deposit amount must be more than Rs.100')

                def withdrawAmount(self, amount):
                    if amount < self.initial_balance:
                        self.initial_balance -= amount
                        print(f'Rs.{amount} has been withdrawn from A/C no. {self.account_number}.')
                    else:
                        raise DepositAmountError('Deposit amount must be more than Rs.100.')

    def show_details(self):
        print(f'name: {self.name}')
        print(f'job: {self.job}')
        print(f'initial_balance: {self.initial_balance}')
        print(f'Account Number: {self.Account_Number}')

# %%
b = Bank('Shyam', 'Analyst', 200)
b.show_details
# Out:
# <bound method Bank.show_details of <__main__.Bank object at 0x000002AED9AF0050>>
